# %% [markdown]
# # Code to produce the cutouts for the MIRI data (DONE)
#
# Let's start with the imports

# %%
from astropy.io import fits
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from astropy.nddata import Cutout2D
import astropy.units as u
import matplotlib.pyplot as plt
import numpy as np
import os
import glob

# %% [markdown]
# Load the catalogue and obtain IDs and coordinates of each galaxy

# %%
# Load target catalogue
with fits.open('./cat_targets.fits') as catalog_hdul:
    catalog_hdul.info()
    cat_data = catalog_hdul[1].data  # Extract data from table
    cat_header = catalog_hdul[1].header
    ids = cat_data['id']
    ra = cat_data['ra']
    dec = cat_data['dec']
# Out:
# Filename: ./cat_targets.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     61   151R x 23C   [K, D, D, D, D, D, K, 4A, K, D, D, D, K, D, D, D, D, D, D, D, D, K, K]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/myenv/lib/python3.12/site-packages/numpy/core/records.py:453, in recarray.__getattribute__(self, attr)
#     452 try:
# --> 453     res = fielddict[attr][:2]
#     454 except (TypeError, KeyError) as e:
#
# KeyError: 'rows'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       7     ra = cat_data['ra']
#       8     dec = cat_data['dec']
# ---> 10 print(cat_data.rows)
#
# File ~/myenv/lib/python3.12/site-packages/astropy/io/fits/fitsrec.py:501, in FITS_rec.__getattribute__(self, attr)
#     498     return self.field(attr)
#     500 # If not, just let the usual np.recarray override deal with it.
# --> 501 return super().__getattribute__(attr)
#
# File ~/myenv/lib/python3.12/site-packages/numpy/core/records.py:455, in recarray.__getattribute__(self, attr)
#     453     res = fielddict[attr][:2]
#     454 except (TypeError, KeyError) as e:
# --> 455     raise AttributeError("recarray has no attribute %s" % attr) from e
#     456 obj = self.getfield(*res)
#     458 # At this point obj will always be a recarray, since (see
#     459 # PyArray_GetField) the type of obj is inherited. Next, if obj.dtype is
#     460 # non-structured, convert it to an ndarray. Then if obj is structured
#     461 # with void type convert it to the same dtype.type (eg to preserve
#     462 # numpy.record type if present), since nested structured fields do not
#     463 # inherit type. Don't do this for non-void structures though.
#
# AttributeError: recarray has no attribute rows

# %% [markdown]
# # Determine cutout dimensions by converting pixels

# %% [markdown]
# Now let's inspect Amirs NIRCam images to see what dimensions he chose:

# %%
nircam_amir = '/home/bpc/University/master/Red_Cardinal/NIRCam/Amir/7102_F090W_cutout.fits'
nircam_tile = '/home/bpc/University/master/Red_Cardinal/NIRCam/COSMOS-1-Tile-24/jw01837-o039_t043_nircam_clear-f090w_i2d.fits'

# Load the NIRCam FITS file
with fits.open(nircam_amir) as nircam_hdul:
    nircam_hdul.info()
    nircam_data = nircam_hdul[1].data
    nircam_header = nircam_hdul[1].header
    wcs = WCS(nircam_header)
# Out:
# Filename: /home/bpc/University/master/Red_Cardinal/NIRCam/Amir/7102_F090W_cutout.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     377   ()
#   1  SCI           1 ImageHDU        81   (167, 167)   float32
#   2  ERR           1 ImageHDU        81   (167, 167)   float32
#   3  WHT           1 ImageHDU        81   (167, 167)   float32
#   4  EXP           1 ImageHDU        81   (167, 167)   float32
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -95.618476 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.375750 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1600118801.710 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %% [markdown]
# Let's look at the NIRCam documentation:
#
# ![NIRCam field of view and pixel sizes](./NIRCam_FOV.png)

# %% [markdown]
# So we find that in the short filters we have 0.031"/pix and Amir used 167 x 167 pixels. So we know that the total FOV is around 63.74" x 63.74". Now we need to translate this to MIRI:
#
# ![MIRI FOV](./MIRI_FOV.jpeg)
# ![MIRI FOV](./MIRI_pixel_sizes.png)

# %% [markdown]
# So takin this conversion of pixels to angular resolution we find that MIRI pixels are on average about 3.5 times larger than NIRCam pixels, so we just need to divide 167 by 3.55, which leaves us with ~48 pixels in MIRI.

# %% [markdown]
# # Create cutouts for PRIMER

# %%
# Define cutout size (in pixels)
cutout_size = (48, 48)

counts = 0
total = len(ra)

# Load datasets
primer = '/home/bpc/University/master/Red_Cardinal/MIRI/PRIMER/'
primer_data = glob.glob(os.path.join(primer, "*.fits"))
print(f"Found {len(primer_data)} FITS files.")

# Create output directory
output_dir = "./cutouts"

# Load the MIRI FITS file
for data in primer_data:
    with fits.open(data) as miri_hdul:
        miri_data = miri_hdul[1].data
        miri_header = miri_hdul[1].header
        wcs = WCS(miri_header)

    if "f770w" in data: filter = "F770W"
    if "f1800w" in data: filter = "F1800W"
    
    # Loop through the galaxies
    for i in range(len(ra)):
        target_coord = SkyCoord(ra[i], dec[i], unit=(u.deg, u.deg))

        # Check if the galaxy is inside the mapped region
        x, y = wcs.world_to_pixel(target_coord)
        if (0 <= x < miri_data.shape[1]) and (0 <= y < miri_data.shape[0]):
            
            # Extract the cutout
            cutout = Cutout2D(miri_data, target_coord, cutout_size, wcs=wcs, mode='partial')

            # Check if galaxy is visible
            nans = np.isnan(cutout.data).sum()
            nan_ratio = nans/cutout.data.size
            
            if nan_ratio < 0.4: 

                # Save the cutout
                plt.figure(figsize=(6, 6))
                plt.imshow(cutout.data, origin='lower', cmap='gray')
                plt.colorbar()
                plt.title(f'PRIMER: {ids[i]} at {filter}')

                png_filename = os.path.join(output_dir, f"{ids[i]}_{filter}_cutout_primer.png")
                plt.savefig(png_filename)
                plt.close()
                
                counts += 1
                
                # Create a new FITS HDU list to store cutout data
                hdu_list = fits.HDUList()
                hdu_list.append(fits.PrimaryHDU(header=miri_hdul[0].header))
                hdu_list.append(fits.ImageHDU(data=cutout.data, header=cutout.wcs.to_header()))
                
                for ext in range(2, len(miri_hdul)):
                    hdu_list.append(fits.ImageHDU(data=miri_hdul[ext].data, header=miri_hdul[ext].header))

                # Save the cutout FITS file
                fits_filename = os.path.join(output_dir, f"{ids[i]}_{filter}_cutout_primer.fits")
                hdu_list.writeto(fits_filename, overwrite=True)
                    
                #print(f"Saved: object {ids[i]} with filter {filter}")
                
            else:
                #print(f"Skipping cutout for target {ids[i]} with filter {filter}: Too many nans in frame")    
                continue
        else:
            #print(f"Skipping target {ids[i]}: Outside mapped region")
            continue
print(f"Produced cutouts for {counts} of {total} galaxies in the catalogue.")
# Out:
# Found 4 FITS files.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-27T14:21:36.255' from MJD-BEG.
# Set DATE-AVG to '2023-05-14T18:14:40.253' from MJD-AVG.
# Set DATE-END to '2023-05-26T19:47:42.198' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -116.853069 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -13.409758 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1412220181.737 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-12-26T19:58:06.960' from MJD-BEG.
# Set DATE-AVG to '2023-01-01T12:00:51.883' from MJD-AVG.
# Set DATE-END to '2023-01-06T04:05:17.902' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   100.077856 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.121531 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1684160522.172 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-27T13:37:59.320' from MJD-BEG.
# Set DATE-AVG to '2023-05-14T17:30:54.860' from MJD-AVG.
# Set DATE-END to '2023-05-26T19:03:43.033' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -116.891759 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -13.386215 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1411888769.318 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-12-26T21:35:09.139' from MJD-BEG.
# Set DATE-AVG to '2023-01-01T15:58:38.112' from MJD-AVG.
# Set DATE-END to '2023-01-06T04:49:11.500' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   100.085113 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.112615 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1684267574.210 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Produced cutouts for 104 of 151 galaxies in the catalogue.

# %% [markdown]
# # Create cutouts for COSMOS-Web

# %%
# Define cutout size (in pixels)
cutout_size = (48, 48)

# Load datasets
cweb = "/home/bpc/University/master/Red_Cardinal/MIRI/COSMOS-Web/"
cweb_data = glob.glob(os.path.join(cweb, "*.fits"))
print(f"Found {len(cweb_data)} FITS files.")

# Create output directory
output_dir = "./cutouts"
os.makedirs(output_dir, exist_ok=True)

counts = 0
total = len(ra)

for data in cweb_data:
    with fits.open(data) as miri_hdul:
        miri_data = miri_hdul[1].data
        miri_header = miri_hdul[1].header
        wcs = WCS(miri_header)

    # Loop over all galaxies first
    for i in range(len(ra)):
        target_coord = SkyCoord(ra[i], dec[i], unit=(u.deg, u.deg))
        found = False  # Track if the galaxy was mapped

        filter = "F770W"

        # Check if the galaxy is inside the mapped region
        x, y = wcs.world_to_pixel(target_coord)
        if (0 <= x < miri_data.shape[1]) and (0 <= y < miri_data.shape[0]):
            found = True  # The galaxy was mapped

            # Extract the cutout
            cutout = Cutout2D(miri_data, target_coord, cutout_size, wcs=wcs, mode="partial")

            # Ensure cutout is valid
            if cutout.data is None or cutout.data.size == 0:
                #print(f"Skipping {ids[i]}: Empty cutout")
                continue

            # Check for NaN ratio
            nans = np.isnan(cutout.data).sum()
            nan_ratio = nans / cutout.data.size

            if nan_ratio < 0.4:
                # Save PNG preview
                plt.figure(figsize=(6, 6))
                plt.imshow(cutout.data, origin="lower", cmap="gray")
                plt.colorbar()
                plt.title(f'COSMOS-Web: {ids[i]} at {filter}')

                png_filename = os.path.join(output_dir, f"{ids[i]}_{filter}_cutout_cweb.png")
                plt.savefig(png_filename)
                plt.close()

                counts += 1

                # Save the cutout FITS file
                hdu_list = fits.HDUList()
                hdu_list.append(fits.PrimaryHDU(header=miri_hdul[0].header))
                hdu_list.append(fits.ImageHDU(data=cutout.data, header=cutout.wcs.to_header()))

                for ext in range(2, len(miri_hdul)):
                    if miri_hdul[ext].data is not None:
                        hdu_list.append(fits.ImageHDU(data=miri_hdul[ext].data, header=miri_hdul[ext].header))

                fits_filename = os.path.join(output_dir, f"{ids[i]}_{filter}_cutout_cweb.fits")
                hdu_list.writeto(fits_filename, overwrite=True)

                #print(f"Saved: {ids[i]} at {filter}")
            else:
                #print(f"Skipping {ids[i]}: Too many NaNs ({nan_ratio:.2f})")
                continue
        else:
            continue  # Galaxy is outside the mapped region

    if not found:
        #print(f"Skipping {ids[i]}: Not found in any FITS file")
        continue
    
print(f"Produced cutouts for {counts} of {total} galaxies in the catalogue.")
# Out:
# Found 164 FITS files.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-07T00:03:29.942' from MJD-BEG.
# Set DATE-AVG to '2024-01-07T00:33:34.781' from MJD-AVG.
# Set DATE-END to '2024-01-07T01:03:43.107' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.514457 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.978885 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1686159123.800 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-30T22:21:46.618' from MJD-BEG.
# Set DATE-AVG to '2023-12-30T22:51:50.121' from MJD-AVG.
# Set DATE-END to '2023-12-30T23:21:48.712' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.557406 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.880269 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695431085.486 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T23:06:26.971' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T23:36:36.346' from MJD-AVG.
# Set DATE-END to '2023-04-11T00:06:42.952' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -142.769118 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.268650 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1267772074.933 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T00:24:03.606' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T00:54:12.637' from MJD-AVG.
# Set DATE-END to '2023-04-11T01:24:14.020' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -142.666984 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.216279 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1268089069.933 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-12T00:49:21.728' from MJD-BEG.
# Set DATE-AVG to '2023-04-12T01:19:27.599' from MJD-AVG.
# Set DATE-END to '2023-04-12T01:49:29.326' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -140.760768 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.230824 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1274254114.571 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-28T03:06:29.947' from MJD-BEG.
# Set DATE-AVG to '2023-12-28T03:36:38.634' from MJD-AVG.
# Set DATE-END to '2023-12-28T04:06:37.609' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.153056 from OBSGEO-[XYZ].
# Set OBSGEO-B to     9.000031 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696585381.847 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T13:35:07.323' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T14:05:09.410' from MJD-AVG.
# Set DATE-END to '2024-01-06T14:33:57.224' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.455798 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.954233 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1686832805.214 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-05T21:51:26.914' from MJD-BEG.
# Set DATE-AVG to '2024-01-05T22:21:34.569' from MJD-AVG.
# Set DATE-END to '2024-01-05T22:51:34.576' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.368276 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.922126 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687846329.759 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-04T14:43:09.391' from MJD-BEG.
# Set DATE-AVG to '2024-01-04T14:55:13.687' from MJD-AVG.
# Set DATE-END to '2024-01-04T15:06:50.239' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.196032 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.875463 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689821617.289 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-12T12:42:05.531' from MJD-BEG.
# Set DATE-AVG to '2023-12-12T13:12:06.922' from MJD-AVG.
# Set DATE-END to '2023-12-12T13:42:07.625' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    92.998713 from OBSGEO-[XYZ].
# Set OBSGEO-B to    11.250875 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1673739679.113 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T17:10:02.139' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T17:40:10.458' from MJD-AVG.
# Set DATE-END to '2023-04-11T18:10:12.553' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.353742 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.538996 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1272284785.109 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-30T14:18:15.703' from MJD-BEG.
# Set DATE-AVG to '2023-12-30T14:48:27.838' from MJD-AVG.
# Set DATE-END to '2023-12-30T15:18:26.116' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.509774 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.890265 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695677965.998 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-05T15:58:08.636' from MJD-BEG.
# Set DATE-AVG to '2024-04-05T16:28:11.731' from MJD-AVG.
# Set DATE-END to '2024-04-05T16:58:16.234' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.373111 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.779609 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1263768560.485 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-12T04:35:26.387' from MJD-BEG.
# Set DATE-AVG to '2023-04-12T05:05:21.914' from MJD-AVG.
# Set DATE-END to '2023-04-12T05:35:17.409' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -140.470464 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.079420 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1275235743.020 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T12:59:04.410' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T13:29:18.633' from MJD-AVG.
# Set DATE-END to '2023-04-10T13:59:34.216' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -143.572396 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.679001 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1265324563.550 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-29T00:24:23.268' from MJD-BEG.
# Set DATE-AVG to '2023-12-29T00:54:19.803' from MJD-AVG.
# Set DATE-END to '2023-12-29T01:24:14.226' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.282585 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.953305 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696453646.252 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T13:16:44.398' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T13:46:32.253' from MJD-AVG.
# Set DATE-END to '2023-04-09T14:14:58.268' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.480436 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.642566 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1259825864.177 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-15T07:28:39.452' from MJD-BEG.
# Set DATE-AVG to '2023-04-15T07:58:41.883' from MJD-AVG.
# Set DATE-END to '2023-04-15T08:28:35.978' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -134.920926 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -2.882216 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1296461400.780 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-15T06:15:34.752' from MJD-BEG.
# Set DATE-AVG to '2023-04-15T06:45:42.063' from MJD-AVG.
# Set DATE-END to '2023-04-15T07:15:50.734' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -135.007764 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -2.834872 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1296089415.554 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T12:16:29.631' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T12:46:42.814' from MJD-AVG.
# Set DATE-END to '2024-01-06T13:16:40.045' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.448477 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.951335 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1686917268.913 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-07T04:55:33.244' from MJD-BEG.
# Set DATE-AVG to '2023-04-07T05:25:29.419' from MJD-AVG.
# Set DATE-END to '2023-04-07T05:55:27.018' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -150.157729 from OBSGEO-[XYZ].
# Set OBSGEO-B to     4.934136 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1248115169.830 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T10:55:47.076' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T11:25:50.555' from MJD-AVG.
# Set DATE-END to '2024-01-06T11:55:46.418' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.440969 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.948402 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687003986.020 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-17T13:42:50.600' from MJD-BEG.
# Set DATE-AVG to '2024-04-17T13:55:35.840' from MJD-AVG.
# Set DATE-END to '2024-04-17T14:08:14.104' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -126.498137 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -10.090524 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1378377090.609 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T07:42:06.529' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T08:12:09.640' from MJD-AVG.
# Set DATE-END to '2023-04-09T08:42:08.623' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.934672 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.869592 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1258580201.074 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-15T05:02:41.188' from MJD-BEG.
# Set DATE-AVG to '2023-04-15T05:32:51.611' from MJD-AVG.
# Set DATE-END to '2023-04-15T06:02:48.850' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -135.094495 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -2.787618 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1295719281.149 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-29T06:51:50.349' from MJD-BEG.
# Set DATE-AVG to '2023-12-29T07:21:50.684' from MJD-AVG.
# Set DATE-END to '2023-12-29T07:51:46.875' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.321631 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.940726 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696368948.347 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-14T04:39:11.434' from MJD-BEG.
# Set DATE-AVG to '2023-04-14T05:09:14.209' from MJD-AVG.
# Set DATE-END to '2023-04-14T05:39:19.032' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -136.859829 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -1.832807 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1288477320.085 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-05T00:21:37.549' from MJD-BEG.
# Set DATE-AVG to '2024-01-05T00:51:50.044' from MJD-AVG.
# Set DATE-END to '2024-01-05T01:21:53.531' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.249337 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.887550 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689218019.567 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-27T23:10:00.841' from MJD-BEG.
# Set DATE-AVG to '2023-12-27T23:40:09.512' from MJD-AVG.
# Set DATE-END to '2023-12-28T00:10:14.006' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.128984 from OBSGEO-[XYZ].
# Set OBSGEO-B to     9.009551 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696584237.014 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-12T09:41:20.929' from MJD-BEG.
# Set DATE-AVG to '2023-04-12T10:11:20.608' from MJD-AVG.
# Set DATE-END to '2023-04-12T10:41:17.519' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -140.079296 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -0.125139 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1276576971.221 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-12T02:03:32.988' from MJD-BEG.
# Set DATE-AVG to '2023-04-12T02:33:31.587' from MJD-AVG.
# Set DATE-END to '2023-04-12T03:03:29.514' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -140.665391 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.181120 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1274575339.599 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-07T03:00:19.147' from MJD-BEG.
# Set DATE-AVG to '2024-01-07T03:30:35.098' from MJD-AVG.
# Set DATE-END to '2024-01-07T04:00:46.201' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.531081 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.986291 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1685970232.087 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T05:46:06.644' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T06:16:06.995' from MJD-AVG.
# Set DATE-END to '2023-04-10T06:46:00.418' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -144.149259 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.971988 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1263616032.174 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-29T05:38:59.537' from MJD-BEG.
# Set DATE-AVG to '2023-12-29T06:09:10.296' from MJD-AVG.
# Set DATE-END to '2023-12-29T06:39:07.199' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.314299 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.943034 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696386421.992 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-04T16:43:30.248' from MJD-BEG.
# Set DATE-AVG to '2024-01-04T17:13:35.439' from MJD-AVG.
# Set DATE-END to '2024-01-04T17:43:32.342' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.207126 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.877806 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689696840.764 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T05:35:21.175' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T06:05:29.142' from MJD-AVG.
# Set DATE-END to '2024-01-06T06:35:31.588' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.411217 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.937182 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687348322.357 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T13:33:26.312' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T14:03:30.495' from MJD-AVG.
# Set DATE-END to '2023-04-11T14:33:33.974' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.634818 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.684562 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1271367790.794 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-29T03:06:18.906' from MJD-BEG.
# Set DATE-AVG to '2023-12-29T03:36:19.265' from MJD-AVG.
# Set DATE-END to '2023-12-29T04:06:18.248' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.298918 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.947958 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696420723.761 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-14T08:32:48.429' from MJD-BEG.
# Set DATE-AVG to '2023-04-14T09:02:53.964' from MJD-AVG.
# Set DATE-END to '2023-04-14T09:32:53.274' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -136.574969 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -1.985984 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1289609358.542 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-14T05:56:48.070' from MJD-BEG.
# Set DATE-AVG to '2023-04-14T06:27:01.245' from MJD-AVG.
# Set DATE-END to '2023-04-14T06:57:03.987' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -136.765066 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -1.883726 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1288852396.703 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-07T14:59:57.063' from MJD-BEG.
# Set DATE-AVG to '2024-04-07T15:30:03.294' from MJD-AVG.
# Set DATE-END to '2024-04-07T16:00:01.909' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.888394 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -1.104648 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1278252598.654 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-17T17:45:14.906' from MJD-BEG.
# Set DATE-AVG to '2024-04-17T18:15:23.945' from MJD-AVG.
# Set DATE-END to '2024-04-17T18:45:30.887' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -126.264434 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -10.231778 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1380302513.230 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-05-17T12:06:28.834' from MJD-BEG.
# Set DATE-AVG to '2024-05-17T12:19:14.042' from MJD-AVG.
# Set DATE-END to '2024-05-17T12:31:52.338' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -97.821902 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -28.137602 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1645762572.625 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T18:20:40.810' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T18:50:39.433' from MJD-AVG.
# Set DATE-END to '2024-01-06T19:20:34.584' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.482438 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.965103 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1686526293.163 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-01-06T02:02:52.196' from MJD-BEG.
# Set DATE-AVG to '2023-01-06T02:32:51.843' from MJD-AVG.
# Set DATE-END to '2023-01-06T03:02:48.722' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.487173 from OBSGEO-[XYZ].
# Set OBSGEO-B to     7.466098 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695419458.051 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-05T17:19:02.264' from MJD-BEG.
# Set DATE-AVG to '2024-04-05T17:31:55.136' from MJD-AVG.
# Set DATE-END to '2024-04-05T17:44:42.471' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.270748 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.725197 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1264155244.601 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-04T20:24:54.651' from MJD-BEG.
# Set DATE-AVG to '2024-01-04T20:54:55.658' from MJD-AVG.
# Set DATE-END to '2024-01-04T21:24:48.329' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.227529 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.882351 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689466151.154 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T18:27:44.343' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T18:57:38.766' from MJD-AVG.
# Set DATE-END to '2023-04-11T19:27:32.548' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.253134 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.486812 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1272615573.082 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T06:29:21.286' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T06:59:22.309' from MJD-AVG.
# Set DATE-END to '2023-04-09T07:29:20.563' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -146.033693 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.918959 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1258311824.478 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-27T21:50:35.981' from MJD-BEG.
# Set DATE-AVG to '2023-12-27T22:20:40.508' from MJD-AVG.
# Set DATE-END to '2023-12-27T22:50:38.075' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.120895 from OBSGEO-[XYZ].
# Set OBSGEO-B to     9.012809 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696582030.874 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-04T13:23:00.180' from MJD-BEG.
# Set DATE-AVG to '2024-01-04T13:53:02.931' from MJD-AVG.
# Set DATE-END to '2024-01-04T14:22:59.458' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.188641 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.873953 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689904464.932 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-12T07:06:57.642' from MJD-BEG.
# Set DATE-AVG to '2023-04-12T07:36:58.705' from MJD-AVG.
# Set DATE-END to '2023-04-12T08:06:56.984' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -140.276476 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -0.021946 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1275898205.843 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-17T16:26:28.894' from MJD-BEG.
# Set DATE-AVG to '2024-04-17T16:56:43.149' from MJD-AVG.
# Set DATE-END to '2024-04-17T17:26:44.876' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -126.340288 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -10.185927 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1379676597.421 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T09:36:15.606' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T10:06:20.797' from MJD-AVG.
# Set DATE-END to '2023-04-11T10:36:26.020' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.943665 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.844132 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1270372227.275 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T11:44:55.903' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T12:15:00.774' from MJD-AVG.
# Set DATE-END to '2023-04-10T12:45:00.748' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -143.670930 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.729148 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1265029848.851 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-30T16:58:25.869' from MJD-BEG.
# Set DATE-AVG to '2023-12-30T17:28:38.028' from MJD-AVG.
# Set DATE-END to '2023-12-30T17:58:41.851' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.525581 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.886819 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695599170.992 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T08:59:54.344' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T09:30:00.599' from MJD-AVG.
# Set DATE-END to '2023-04-10T10:00:04.758' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -143.890620 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.840803 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1264377041.671 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T02:57:10.384' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T03:27:08.991' from MJD-AVG.
# Set DATE-END to '2024-01-06T03:57:04.158' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.396560 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.931891 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687518245.814 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-30T15:35:41.202' from MJD-BEG.
# Set DATE-AVG to '2023-12-30T16:05:42.969' from MJD-AVG.
# Set DATE-END to '2023-12-30T16:35:40.544' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.517418 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.888583 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695640250.730 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T18:03:07.977' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T18:33:11.784' from MJD-AVG.
# Set DATE-END to '2023-04-10T19:03:12.822' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -143.169388 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.473469 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1266542432.148 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T12:10:36.141' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T12:40:32.988' from MJD-AVG.
# Set DATE-END to '2023-04-11T13:10:27.099' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.742559 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.740273 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1271019065.932 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T16:49:07.789' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T17:19:05.356' from MJD-AVG.
# Set DATE-END to '2023-04-10T17:49:01.563' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -143.267312 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.523473 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1266244658.035 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T04:02:24.782' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T04:32:22.341' from MJD-AVG.
# Set DATE-END to '2023-04-09T05:02:18.492' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -146.233969 from OBSGEO-[XYZ].
# Set OBSGEO-B to     3.018672 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1257772462.914 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-23T13:05:37.076' from MJD-BEG.
# Set DATE-AVG to '2024-04-23T13:18:16.092' from MJD-AVG.
# Set DATE-END to '2024-04-23T13:30:52.324' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -118.667209 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -14.816613 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1446393634.593 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-28T00:31:02.852' from MJD-BEG.
# Set DATE-AVG to '2023-12-28T01:01:08.739' from MJD-AVG.
# Set DATE-END to '2023-12-28T01:31:04.946' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.137235 from OBSGEO-[XYZ].
# Set OBSGEO-B to     9.006259 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696585542.539 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T16:12:25.457' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T16:24:27.673' from MJD-AVG.
# Set DATE-END to '2024-01-06T16:35:57.985' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.470462 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.960154 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1686663904.262 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T08:54:46.205' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T09:24:53.844' from MJD-AVG.
# Set DATE-END to '2023-04-09T09:54:59.371' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.835871 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.820290 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1258849110.518 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-28T10:16:19.042' from MJD-BEG.
# Set DATE-AVG to '2023-12-28T10:46:33.871' from MJD-AVG.
# Set DATE-END to '2023-12-28T11:16:34.883' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.196736 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.983423 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696566832.109 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T06:55:59.871' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T07:26:11.654' from MJD-AVG.
# Set DATE-END to '2023-04-11T07:56:40.813' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -142.152979 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.952049 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1269704592.364 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T11:57:19.538' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T12:27:24.385' from MJD-AVG.
# Set DATE-END to '2023-04-09T12:57:32.704' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.588055 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.696437 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1259528573.191 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-15T10:35:55.857' from MJD-BEG.
# Set DATE-AVG to '2023-04-15T11:05:51.336' from MJD-AVG.
# Set DATE-END to '2023-04-15T11:35:44.063' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -134.698913 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -3.003406 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1297418826.056 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T22:13:21.290' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T22:43:21.977' from MJD-AVG.
# Set DATE-END to '2023-04-11T23:13:26.135' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -140.961694 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.335410 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1273581478.266 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T01:26:16.023' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T01:56:26.070' from MJD-AVG.
# Set DATE-END to '2023-04-09T02:26:31.941' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -146.447203 from OBSGEO-[XYZ].
# Set OBSGEO-B to     3.124637 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1257203257.437 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-29T08:09:07.529' from MJD-BEG.
# Set DATE-AVG to '2023-12-29T08:39:01.632' from MJD-AVG.
# Set DATE-END to '2023-12-29T09:09:04.054' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.329404 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.938306 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696349632.185 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-14T07:15:25.761' from MJD-BEG.
# Set DATE-AVG to '2023-04-14T07:45:24.998' from MJD-AVG.
# Set DATE-END to '2023-04-14T08:15:22.207' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -136.669191 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -1.935280 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1289233407.122 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-30T21:03:17.311' from MJD-BEG.
# Set DATE-AVG to '2023-12-30T21:33:10.358' from MJD-AVG.
# Set DATE-END to '2023-12-30T22:03:02.701' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.549691 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.881809 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695472981.561 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T17:10:32.544' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T17:40:33.239' from MJD-AVG.
# Set DATE-END to '2023-04-09T18:10:26.318' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.164255 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.483996 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1260707127.063 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-05T01:41:13.545' from MJD-BEG.
# Set DATE-AVG to '2024-01-05T02:11:18.376' from MJD-AVG.
# Set DATE-END to '2024-01-05T02:41:12.823' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.256670 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.889378 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689134263.260 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-12T03:21:01.304' from MJD-BEG.
# Set DATE-AVG to '2023-04-12T03:51:05.103' from MJD-AVG.
# Set DATE-END to '2023-04-12T04:21:14.469' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -140.565910 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.129237 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1274911721.017 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-28T05:39:32.786' from MJD-BEG.
# Set DATE-AVG to '2023-12-28T06:09:31.745' from MJD-AVG.
# Set DATE-END to '2023-12-28T06:39:29.312' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.168621 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.994015 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696581814.751 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T09:33:44.073' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T10:03:53.064' from MJD-AVG.
# Set DATE-END to '2024-01-06T10:33:54.423' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.433343 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.945465 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687092155.716 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-14T09:49:29.512' from MJD-BEG.
# Set DATE-AVG to '2023-04-14T10:19:33.327' from MJD-AVG.
# Set DATE-END to '2023-04-14T10:49:39.926' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -136.481717 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -2.036202 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1289982922.477 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-07T02:16:15.749' from MJD-BEG.
# Set DATE-AVG to '2023-04-07T02:46:26.516' from MJD-AVG.
# Set DATE-END to '2023-04-07T03:16:31.731' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -150.382647 from OBSGEO-[XYZ].
# Set OBSGEO-B to     5.041646 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1247613138.823 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-01-05T19:26:12.923' from MJD-BEG.
# Set DATE-AVG to '2023-01-05T19:56:18.442' from MJD-AVG.
# Set DATE-END to '2023-01-05T20:26:20.521' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.440411 from OBSGEO-[XYZ].
# Set OBSGEO-B to     7.467605 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695423379.830 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-12T08:24:17.638' from MJD-BEG.
# Set DATE-AVG to '2023-04-12T08:54:28.397' from MJD-AVG.
# Set DATE-END to '2023-04-12T09:24:33.619' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -140.177648 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -0.073647 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1276237725.031 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T10:52:59.505' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T11:23:06.776' from MJD-AVG.
# Set DATE-END to '2023-04-11T11:53:12.671' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.843626 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.792489 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1270693330.825 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-15T08:41:19.128' from MJD-BEG.
# Set DATE-AVG to '2023-04-15T08:54:02.288' from MJD-AVG.
# Set DATE-END to '2023-04-15T09:06:42.695' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -134.834697 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -2.929260 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1296832166.104 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T06:54:15.506' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T07:24:18.257' from MJD-AVG.
# Set DATE-END to '2024-01-06T07:54:23.104' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.418536 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.939883 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687263535.299 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T14:17:03.254' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T14:47:12.949' from MJD-AVG.
# Set DATE-END to '2023-04-10T15:17:13.667' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -143.468871 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.626270 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1265635490.845 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T01:38:26.002' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T02:08:23.905' from MJD-AVG.
# Set DATE-END to '2023-04-11T02:38:19.712' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -142.569218 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.166108 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1268393744.472 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-06T23:40:54.222' from MJD-BEG.
# Set DATE-AVG to '2023-04-07T00:11:00.789' from MJD-AVG.
# Set DATE-END to '2023-04-07T00:41:07.388' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -150.602385 from OBSGEO-[XYZ].
# Set OBSGEO-B to     5.146431 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1247128011.167 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-28T11:34:03.921' from MJD-BEG.
# Set DATE-AVG to '2023-12-28T12:04:08.072' from MJD-AVG.
# Set DATE-END to '2023-12-28T12:34:08.767' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.204626 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.980516 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696560658.714 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-06T15:12:17.963' from MJD-BEG.
# Set DATE-AVG to '2024-04-06T15:42:20.770' from MJD-AVG.
# Set DATE-END to '2024-04-06T16:12:17.304' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -143.629450 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -0.154988 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1270667888.170 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T14:52:21.750' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T15:22:23.829' from MJD-AVG.
# Set DATE-END to '2024-01-06T15:52:26.596' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.462995 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.957120 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1686749854.847 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-23T21:57:27.390' from MJD-BEG.
# Set DATE-AVG to '2023-04-23T22:27:28.101' from MJD-AVG.
# Set DATE-END to '2023-04-23T22:57:29.484' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -121.735163 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -10.454902 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1372923875.215 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T19:20:50.116' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T19:50:51.851' from MJD-AVG.
# Set DATE-END to '2023-04-10T20:20:54.962' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -143.066681 from OBSGEO-[XYZ].
# Set OBSGEO-B to     1.420978 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1266856034.801 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-30T12:01:57.471' from MJD-BEG.
# Set DATE-AVG to '2023-12-30T12:32:01.974' from MJD-AVG.
# Set DATE-END to '2023-12-30T13:01:59.564' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.496300 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.893303 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695742648.509 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-05T20:32:40.903' from MJD-BEG.
# Set DATE-AVG to '2024-01-05T21:02:51.326' from MJD-AVG.
# Set DATE-END to '2024-01-05T21:32:56.884' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.360998 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.919709 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687930750.539 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-28T06:56:25.005' from MJD-BEG.
# Set DATE-AVG to '2023-12-28T07:08:39.717' from MJD-AVG.
# Set DATE-END to '2023-12-28T07:20:16.989' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.176434 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.991036 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696578752.547 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-01-05T22:00:22.322' from MJD-BEG.
# Set DATE-AVG to '2023-01-05T22:30:31.345' from MJD-AVG.
# Set DATE-END to '2023-01-05T23:00:29.920' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.458542 from OBSGEO-[XYZ].
# Set OBSGEO-B to     7.466924 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695424684.134 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-29T11:06:41.150' from MJD-BEG.
# Set DATE-AVG to '2023-12-29T11:36:46.357' from MJD-AVG.
# Set DATE-END to '2023-12-29T12:06:45.996' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.347244 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.932859 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696302240.954 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T05:16:24.906' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T05:46:24.249' from MJD-AVG.
# Set DATE-END to '2023-04-09T06:16:29.816' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -146.133059 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.968454 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1258043644.882 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-05T03:45:10.786' from MJD-BEG.
# Set DATE-AVG to '2024-01-05T04:15:30.905' from MJD-AVG.
# Set DATE-END to '2024-01-05T04:45:51.727' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.268089 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.892303 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689003542.739 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T19:41:38.962' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T20:11:45.177' from MJD-AVG.
# Set DATE-END to '2023-04-11T20:41:52.128' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.157548 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.437194 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1272931105.291 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-10T07:00:09.583' from MJD-BEG.
# Set DATE-AVG to '2023-04-10T07:12:16.663' from MJD-AVG.
# Set DATE-END to '2023-04-10T07:23:50.431' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -144.050351 from OBSGEO-[XYZ].
# ...
# Set DATE-AVG to '2023-04-14T00:58:43.192' from MJD-AVG.
# Set DATE-END to '2023-04-14T01:28:49.095' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -137.166846 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -1.668099 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1287272382.345 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T18:24:32.732' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T18:54:33.083' from MJD-AVG.
# Set DATE-END to '2023-04-09T19:24:34.825' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.064382 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.433816 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1260987929.951 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-05T03:10:26.692' from MJD-BEG.
# Set DATE-AVG to '2024-01-05T03:19:50.732' from MJD-AVG.
# Set DATE-END to '2024-01-05T03:29:13.396' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.264889 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.891474 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689040208.783 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-17T14:24:55.973' from MJD-BEG.
# Set DATE-AVG to '2024-04-17T14:37:33.565' from MJD-AVG.
# Set DATE-END to '2024-04-17T14:50:11.157' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -126.457503 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -10.115082 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1378711227.352 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-01-05T20:43:10.647' from MJD-BEG.
# Set DATE-AVG to '2023-01-05T21:13:14.822' from MJD-AVG.
# Set DATE-END to '2023-01-05T21:43:09.989' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.449456 from OBSGEO-[XYZ].
# Set OBSGEO-B to     7.467250 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695424479.893 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-01-05T23:27:22.285' from MJD-BEG.
# Set DATE-AVG to '2023-01-05T23:57:26.804' from MJD-AVG.
# Set DATE-END to '2023-01-06T00:27:21.627' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   101.468798 from OBSGEO-[XYZ].
# Set OBSGEO-B to     7.466593 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695423833.821 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-04-07T16:12:47.875' from MJD-BEG.
# Set DATE-AVG to '2024-04-07T16:42:46.130' from MJD-AVG.
# Set DATE-END to '2024-04-07T17:12:36.081' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.800741 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -1.152893 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1278653724.897 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-04T17:57:41.508' from MJD-BEG.
# Set DATE-AVG to '2024-01-04T18:27:50.171' from MJD-AVG.
# Set DATE-END to '2024-01-04T18:57:54.674' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.213964 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.879295 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689619701.896 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-05T13:27:21.055' from MJD-BEG.
# Set DATE-AVG to '2024-01-05T13:57:27.646' from MJD-AVG.
# Set DATE-END to '2024-01-05T14:27:31.469' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.321741 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.907347 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1688385503.403 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T19:41:06.725' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T20:11:19.908' from MJD-AVG.
# Set DATE-END to '2024-01-06T20:41:28.211' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.489959 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.968262 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1686440053.421 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-29T01:45:44.671' from MJD-BEG.
# Set DATE-AVG to '2023-12-29T02:15:49.198' from MJD-AVG.
# Set DATE-END to '2023-12-29T02:45:55.085' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.290794 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.950602 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696437551.814 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-29T09:52:32.643' from MJD-BEG.
# Set DATE-AVG to '2023-12-29T10:22:29.202' from MJD-AVG.
# Set DATE-END to '2023-12-29T10:52:26.416' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.339799 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.935115 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696322538.406 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T01:39:08.789' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T02:09:02.180' from MJD-AVG.
# Set DATE-END to '2024-01-06T02:37:50.370' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.389336 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.929341 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687602030.047 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-14T01:56:53.588' from MJD-BEG.
# Set DATE-AVG to '2023-04-14T02:26:58.435' from MJD-AVG.
# Set DATE-END to '2023-04-14T02:56:52.865' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -137.058408 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -1.726228 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1287696183.230 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T08:15:08.091' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T08:45:03.898' from MJD-AVG.
# Set DATE-END to '2023-04-11T09:15:07.368' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -142.049557 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.898750 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1270033757.162 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-05T23:23:32.157' from MJD-BEG.
# Set DATE-AVG to '2024-01-05T23:53:31.468' from MJD-AVG.
# Set DATE-END to '2024-01-06T00:23:31.434' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.376790 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.925004 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687747569.710 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-04T15:24:13.709' from MJD-BEG.
# Set DATE-AVG to '2024-01-04T15:54:26.188' from MJD-AVG.
# Set DATE-END to '2024-01-04T16:24:35.195' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.199818 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.876252 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689779084.772 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T15:53:07.045' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T16:23:02.868' from MJD-AVG.
# Set DATE-END to '2023-04-09T16:53:06.322' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.268851 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.536502 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1260414299.313 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-06T04:15:31.371' from MJD-BEG.
# Set DATE-AVG to '2024-01-06T04:45:26.172' from MJD-AVG.
# Set DATE-END to '2024-01-06T05:15:27.881' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.403818 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.934491 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1687434089.080 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-30T19:36:03.460' from MJD-BEG.
# Set DATE-AVG to '2023-12-30T20:06:16.971' from MJD-AVG.
# Set DATE-END to '2023-12-30T20:36:27.698' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.541110 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.883558 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695518724.230 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-05T12:09:00.004' from MJD-BEG.
# Set DATE-AVG to '2024-01-05T12:39:08.355' from MJD-AVG.
# Set DATE-END to '2024-01-05T13:09:13.234' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.314516 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.905197 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1688469020.707 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-28T01:48:28.351' from MJD-BEG.
# Set DATE-AVG to '2023-12-28T02:18:36.694' from MJD-AVG.
# Set DATE-END to '2023-12-28T02:48:41.517' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.145116 from OBSGEO-[XYZ].
# Set OBSGEO-B to     9.003142 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696585899.756 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-07T07:54:41.201' from MJD-BEG.
# Set DATE-AVG to '2023-04-07T08:24:48.496' from MJD-AVG.
# Set DATE-END to '2023-04-07T08:54:51.615' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -149.905263 from OBSGEO-[XYZ].
# Set OBSGEO-B to     4.813150 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1248685285.626 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T20:59:15.534' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T21:29:19.373' from MJD-AVG.
# Set DATE-END to '2023-04-11T21:59:12.124' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.057296 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.385113 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1273263365.663 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-29T04:19:04.150' from MJD-BEG.
# Set DATE-AVG to '2023-12-29T04:49:08.325' from MJD-AVG.
# Set DATE-END to '2023-12-29T05:19:14.564' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.306250 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.945597 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1696404771.203 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-07T03:36:22.273' from MJD-BEG.
# Set DATE-AVG to '2023-04-07T04:06:23.312' from MJD-AVG.
# Set DATE-END to '2023-04-07T04:36:24.366' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -150.269486 from OBSGEO-[XYZ].
# Set OBSGEO-B to     4.987588 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1247865030.250 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T23:31:00.677' from MJD-BEG.
# Set DATE-AVG to '2023-04-12T00:01:04.836' from MJD-AVG.
# Set DATE-END to '2023-04-12T00:31:02.771' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -140.861617 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.283339 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1273915815.110 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-11T14:51:02.947' from MJD-BEG.
# Set DATE-AVG to '2023-04-11T15:21:08.146' from MJD-AVG.
# Set DATE-END to '2023-04-11T15:51:07.793' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -141.533997 from OBSGEO-[XYZ].
# Set OBSGEO-B to     0.632386 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1271695507.791 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T14:34:37.673' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T15:04:56.048' from MJD-AVG.
# Set DATE-END to '2023-04-09T15:34:59.159' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -145.374996 from OBSGEO-[XYZ].
# Set OBSGEO-B to     2.589735 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1260118448.079 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-30T13:19:31.290' from MJD-BEG.
# Set DATE-AVG to '2023-12-30T13:31:38.370' from MJD-AVG.
# Set DATE-END to '2023-12-30T13:43:17.706' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    95.503969 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.891563 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1695706110.006 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-05-17T01:46:31.612' from MJD-BEG.
# Set DATE-AVG to '2023-05-17T02:16:47.907' from MJD-AVG.
# Set DATE-END to '2023-05-17T02:46:50.346' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -96.626634 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -25.704944 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1591175077.882 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-12-16T15:14:37.537' from MJD-BEG.
# Set DATE-AVG to '2023-12-16T15:27:24.857' from MJD-AVG.
# Set DATE-END to '2023-12-16T15:40:09.424' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    93.577079 from OBSGEO-[XYZ].
# Set OBSGEO-B to    10.359782 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1680727992.914 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-09T02:45:04.787' from MJD-BEG.
# Set DATE-AVG to '2023-04-09T03:14:53.698' from MJD-AVG.
# Set DATE-END to '2023-04-09T03:44:47.424' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -146.339523 from OBSGEO-[XYZ].
# Set OBSGEO-B to     3.071152 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1257490048.319 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2023-04-15T09:22:53.973' from MJD-BEG.
# Set DATE-AVG to '2023-04-15T09:53:06.452' from MJD-AVG.
# Set DATE-END to '2023-04-15T10:23:07.139' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -134.785403 from OBSGEO-[XYZ].
# Set OBSGEO-B to    -2.956169 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1297044743.994 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Produced cutouts for 67 of 151 galaxies in the catalogue.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-01-04T21:44:49.943' from MJD-BEG.
# Set DATE-AVG to '2024-01-04T22:14:55.166' from MJD-AVG.
# Set DATE-END to '2024-01-04T22:44:57.604' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to    96.234893 from OBSGEO-[XYZ].
# Set OBSGEO-B to     8.884067 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1689382539.343 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %% [markdown]
# So let's check what's wrong with the cutouts that have more than 80% nan entries in our final plots.

# %% [markdown]
# problem_galaxy = './cutouts/8323_F770W_cutout_cweb.fits'
#
# with fits.open(problem_galaxy) as prob_hdul:
#     prob_data = prob_hdul[1].data
#     prob_header = prob_hdul[1].header
#     wcs = WCS(prob_header)
#
# nan_count = np.isnan(prob_data).sum()
# nan_ratio = nan_count / prob_data.size
#
# print(nan_count)
# print(prob_data.size)
# print(nan_ratio)
# #print(prob_data)
#
# nan_count = np.sum(np.isnan(prob_data) | (prob_data <= 0))
# valid_count = np.count_nonzero(~np.isnan(prob_data))
# nan_ratio = 1 - (valid_count / prob_data.size)
#
# print(nan_ratio)
# plt.imshow(np.isnan(prob_data), cmap='gray', origin='lower')
# plt.title('NaN mask')
# plt.show()
